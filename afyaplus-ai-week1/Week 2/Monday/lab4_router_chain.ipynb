# %%
import os 
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
# A low temperature (0.0) removes creative variation, making classification deterministic.
router_llm = ChatOpenAI(model = "gpt-5.0-mini", temperature=0.0)

# %%
router_prompt = ChatPromptTemplate.from_template(
    "Classify the patient's message as exactly one word, either Clinical or Billing \n"
    "Message: {message} \n Classification"
)
